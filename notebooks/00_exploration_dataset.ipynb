# %% [markdown]
# # 00 - Exploration du dataset
#
# Objectif : comprendre la structure de `water_v2` et visualiser quelques images avec leurs annotations.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(ROOT / "src"))

from water_detection_methods.data import find_water_v2_pairs, list_local_images, load_pair
from water_detection_methods.visualization import show_image_mask_overlay

# %%
pairs = find_water_v2_pairs(ROOT / "water_v2")
local_images = list_local_images(ROOT / "IMGs")

print(f"Images annotees water_v2 : {len(pairs)}")
print(f"Images locales IMGs : {len(local_images)}")
pairs[:3]
# Out:
# Images annotees water_v2 : 2400
# Images locales IMGs : 10
# [(WindowsPath('c:/Users/Asus/Desktop/OCP/water-detection-methods/water_v2/JPEGImages/aberlour/2019-08-03-08-00-10.jpg'),
#   WindowsPath('c:/Users/Asus/Desktop/OCP/water-detection-methods/water_v2/Annotations/aberlour/2019-08-03-08-00-10.png')),
#  (WindowsPath('c:/Users/Asus/Desktop/OCP/water-detection-methods/water_v2/JPEGImages/aberlour/2019-08-03-08-03-10.jpg'),
#   WindowsPath('c:/Users/Asus/Desktop/OCP/water-detection-methods/water_v2/Annotations/aberlour/2019-08-03-08-03-10.png')),
#  (WindowsPath('c:/Users/Asus/Desktop/OCP/water-detection-methods/water_v2/JPEGImages/aberlour/2019-08-03-10-30-10.jpg'),
#   WindowsPath('c:/Users/Asus/Desktop/OCP/water-detection-methods/water_v2/Annotations/aberlour/2019-08-03-10-30-10.png'))]

# %%
image, mask = load_pair(*pairs[0], size=(384, 256))
show_image_mask_overlay(image, mask, title=str(pairs[0][0].relative_to(ROOT)))
# Out:
# (<Figure size 1400x400 with 3 Axes>,
#  array([<Axes: title={'center': 'Image'}>,
#         <Axes: title={'center': 'Masque eau'}>,
#         <Axes: title={'center': 'Overlay'}>], dtype=object))
